# %% [markdown]
# ## ANN for 2 layer MCX data fitting HHB2

# %%
import pandas as pd
import glob
import os
import numpy as np

# %% [markdown]
# ### Simulation data

# %%
csv_folder = 'C:/Users/Haiya/2layer_sim/MCX_bbnirs_simulation_2layer/simulations/2layer_simlulation/sim_results/1_4/fd'
GT_folder = 'C:/Users/Haiya/2layer_sim/MCX_bbnirs_simulation_2layer/simulations/2layer_simlulation/data_generation/split_files/'

# %%
csv_files = glob.glob(os.path.join(csv_folder, '*.csv'))
df_all = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)

# %%
df_all.head()
# Out:
#    ID   Uac_1_1   Udc_1_1  Phase_1_1   Uac_1_2   Udc_1_2  Phase_1_2   Uac_1_3  \
# 0   1  0.000630  0.000665  -0.501516  0.000645  0.000680  -0.494211  0.000654
# 1   2  0.000659  0.000704  -0.528213  0.000675  0.000720  -0.520862  0.000685
# 2   3  0.000677  0.000730  -0.549963  0.000693  0.000747  -0.542363  0.000704
# 3   4  0.000686  0.000749  -0.566580  0.000703  0.000766  -0.558862  0.000714
# 4   5  0.000691  0.000761  -0.578840  0.000708  0.000778  -0.570998  0.000719
#
#     Udc_1_3  Phase_1_3  ...  Phase_4_5   Uac_4_6   Udc_4_6  Phase_4_6  \
# 0  0.000687  -0.479320  ...  -0.956285  0.000022  0.000024  -0.938081
# 1  0.000727  -0.505208  ...  -1.018659  0.000027  0.000030  -1.001600
# 2  0.000755  -0.526124  ...  -1.077448  0.000031  0.000035  -1.060109
# 3  0.000773  -0.542014  ...  -1.130043  0.000034  0.000039  -1.111908
# 4  0.000785  -0.553765  ...  -1.176073  0.000036  0.000042  -1.156740
#
#     Uac_4_7   Udc_4_7  Phase_4_7   Uac_4_8   Udc_4_8  Phase_4_8
# 0  0.000022  0.000024  -0.907132  0.000022  0.000024  -0.899211
# 1  0.000027  0.000030  -0.971622  0.000027  0.000030  -0.959532
# 2  0.000031  0.000035  -1.031858  0.000032  0.000035  -1.016267
# 3  0.000034  0.000039  -1.084599  0.000035  0.000040  -1.067255
# 4  0.000037  0.000043  -1.129599  0.000037  0.000043  -1.110989
#
# [5 rows x 97 columns]

# %%
csv_files = glob.glob(os.path.join(GT_folder, '*.csv'))
GT_all = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)

# %%
GT_all.head
# Out:
# <bound method NDFrame.head of           ID  HBO1  HHB1  HBO2  HHB2  Thickness  complete
# 0          1   5.0   2.5    25    15         10     False
# 1          2   5.0   2.5    25    15         12     False
# 2          3   5.0   2.5    25    15         14     False
# 3          4   5.0   2.5    25    15         16     False
# 4          5   5.0   2.5    25    15         18     False
# ...      ...   ...   ...   ...   ...        ...       ...
# 87841  87842  20.0  12.5    55    35         12     False
# 87842  87843  20.0  12.5    55    35         14     False
# 87843  87844  20.0  12.5    55    35         16     False
# 87844  87845  20.0  12.5    55    35         18     False
# 87845  87846  20.0  12.5    55    35         20     False
#
# [87846 rows x 7 columns]>

# %% [markdown]
# ### Merge data

# %%
GT_all['ID'] = GT_all['ID'].astype(int)
df_all['ID'] = df_all['ID'].astype(int)
GT_all = GT_all.sort_values('ID').reset_index(drop=True)
df_all = df_all.sort_values('ID').reset_index(drop=True)

# %%
merged_df = pd.merge(df_all, GT_all, on='ID', how='inner')

# %%
merged_df.head
# Out:
# <bound method NDFrame.head of       ID   Uac_1_1   Udc_1_1  Phase_1_1   Uac_1_2   Udc_1_2  Phase_1_2  \
# 0      1  0.000630  0.000665  -0.501516  0.000645  0.000680  -0.494211
# 1      2  0.000659  0.000704  -0.528213  0.000675  0.000720  -0.520862
# 2      3  0.000677  0.000730  -0.549963  0.000693  0.000747  -0.542363
# 3      4  0.000686  0.000749  -0.566580  0.000703  0.000766  -0.558862
# 4      5  0.000691  0.000761  -0.578840  0.000708  0.000778  -0.570998
# ..   ...       ...       ...        ...       ...       ...        ...
# 155  156  0.000692  0.000766  -0.584238  0.000710  0.000784  -0.576365
# 156  157  0.000611  0.000640  -0.482166  0.000627  0.000656  -0.475665
# 157  158  0.000649  0.000687  -0.513365  0.000665  0.000703  -0.506709
# 158  159  0.000671  0.000719  -0.538951  0.000688  0.000736  -0.531871
# 159  160  0.000683  0.000741  -0.558647  0.000700  0.000758  -0.551327
#
#       Uac_1_3   Udc_1_3  Phase_1_3  ...  Phase_4_7   Uac_4_8   Udc_4_8  \
# 0    0.000654  0.000687  -0.479320  ...  -0.907132  0.000022  0.000024
# 1    0.000685  0.000727  -0.505208  ...  -0.971622  0.000027  0.000030
# 2    0.000704  0.000755  -0.526124  ...  -1.031858  0.000032  0.000035
# 3    0.000714  0.000773  -0.542014  ...  -1.084599  0.000035  0.000040
# 4    0.000719  0.000785  -0.553765  ...  -1.129599  0.000037  0.000043
# ..        ...       ...        ...  ...        ...       ...       ...
# 155  0.000721  0.000791  -0.559077  ...  -1.152303  0.000038  0.000045
# 156  0.000636  0.000663  -0.462100  ...  -0.857792  0.000020  0.000021
# 157  0.000675  0.000711  -0.492039  ...  -0.930810  0.000025  0.000027
# 158  0.000698  0.000744  -0.516378  ...  -0.998481  0.000030  0.000033
# 159  0.000711  0.000766  -0.534975  ...  -1.057558  0.000034  0.000038
#
#      Phase_4_8  HBO1  HHB1  HBO2  HHB2  Thickness  complete
# 0    -0.899211   5.0   2.5    25    15         10     False
# 1    -0.959532   5.0   2.5    25    15         12     False
# 2    -1.016267   5.0   2.5    25    15         14     False
# 3    -1.067255   5.0   2.5    25    15         16     False
# 4    -1.110989   5.0   2.5    25    15         18     False
# ..         ...   ...   ...   ...   ...        ...       ...
# 155  -1.132938   5.0   2.5    31    21         20     False
# 156  -0.853066   5.0   2.5    31    23         10     False
# 157  -0.921109   5.0   2.5    31    23         12     False
# 158  -0.984520   5.0   2.5    31    23         14     False
# 159  -1.041142   5.0   2.5    31    23         16     False
#
# [160 rows x 103 columns]>

# %%
X = merged_df[df_all.columns.difference(['ID'])]
Y = merged_df[['HBO1', 'HHB1', 'HBO2', 'HHB2', 'Thickness']]

# %%
X
# Out:
#      Phase_1_1  Phase_1_2  Phase_1_3  Phase_1_4  Phase_1_5  Phase_1_6  \
# 0    -0.501516  -0.494211  -0.479320  -0.466597  -0.453209  -0.442392
# 1    -0.528213  -0.520862  -0.505208  -0.492353  -0.478282  -0.467212
# 2    -0.549963  -0.542363  -0.526124  -0.513049  -0.498408  -0.487087
# 3    -0.566580  -0.558862  -0.542014  -0.528792  -0.513907  -0.502234
# 4    -0.578840  -0.570998  -0.553765  -0.540315  -0.525392  -0.513456
# ..         ...        ...        ...        ...        ...        ...
# 155  -0.584238  -0.576365  -0.559077  -0.545656  -0.530728  -0.518724
# 156  -0.482166  -0.475665  -0.462100  -0.450176  -0.437614  -0.427277
# 157  -0.513365  -0.506709  -0.492039  -0.479824  -0.466368  -0.455720
# 158  -0.538951  -0.531871  -0.516378  -0.503774  -0.489527  -0.478537
# 159  -0.558647  -0.551327  -0.534975  -0.522111  -0.507452  -0.496002
#
#      Phase_1_7  Phase_1_8  Phase_2_1  Phase_2_2  ...   Udc_3_7   Udc_3_8  \
# 0    -0.434354  -0.426198  -0.693509  -0.685174  ...  0.000069  0.000069
# 1    -0.458873  -0.450206  -0.736003  -0.725650  ...  0.000080  0.000081
# 2    -0.478677  -0.469506  -0.772475  -0.760532  ...  0.000090  0.000091
# 3    -0.494043  -0.484335  -0.802565  -0.789521  ...  0.000098  0.000099
# 4    -0.505478  -0.495419  -0.825953  -0.812318  ...  0.000103  0.000105
# ..         ...        ...        ...        ...  ...       ...       ...
# 155  -0.510897  -0.500731  -0.836362  -0.822579  ...  0.000106  0.000108
# 156  -0.419505  -0.411771  -0.660450  -0.654636  ...  0.000062  0.000063
# 157  -0.447436  -0.439139  -0.709712  -0.701252  ...  0.000075  0.000076
# 158  -0.470080  -0.461225  -0.752002  -0.741366  ...  0.000086  0.000087
# 159  -0.487771  -0.478274  -0.787137  -0.775018  ...  0.000095  0.000096
#
#       Udc_4_1   Udc_4_2   Udc_4_3   Udc_4_4   Udc_4_5   Udc_4_6   Udc_4_7  \
# 0    0.000024  0.000026  0.000025  0.000025  0.000024  0.000024  0.000024
# 1    0.000030  0.000032  0.000031  0.000031  0.000030  0.000030  0.000030
# 2    0.000035  0.000037  0.000036  0.000036  0.000036  0.000035  0.000035
# 3    0.000039  0.000041  0.000040  0.000040  0.000040  0.000039  0.000039
# 4    0.000043  0.000045  0.000044  0.000044  0.000044  0.000042  0.000043
# ..        ...       ...       ...       ...       ...       ...       ...
# 155  0.000044  0.000047  0.000045  0.000045  0.000045  0.000044  0.000045
# 156  0.000020  0.000022  0.000021  0.000022  0.000021  0.000020  0.000020
# 157  0.000026  0.000028  0.000028  0.000028  0.000028  0.000027  0.000027
# 158  0.000032  0.000034  0.000033  0.000034  0.000033  0.000032  0.000032
# 159  0.000037  0.000039  0.000038  0.000038  0.000038  0.000037  0.000037
#
#       Udc_4_8
# 0    0.000024
# 1    0.000030
# 2    0.000035
# 3    0.000040
# 4    0.000043
# ..        ...
# 155  0.000045
# 156  0.000021
# 157  0.000027
# 158  0.000033
# 159  0.000038
#
# [160 rows x 96 columns]

# %%
Y
# Out:
#      HBO1  HHB1  HBO2  HHB2  Thickness
# 0     5.0   2.5    25    15         10
# 1     5.0   2.5    25    15         12
# 2     5.0   2.5    25    15         14
# 3     5.0   2.5    25    15         16
# 4     5.0   2.5    25    15         18
# ..    ...   ...   ...   ...        ...
# 155   5.0   2.5    31    21         20
# 156   5.0   2.5    31    23         10
# 157   5.0   2.5    31    23         12
# 158   5.0   2.5    31    23         14
# 159   5.0   2.5    31    23         16
#
# [160 rows x 5 columns]

# %%
X = X.to_numpy()
Y = Y.to_numpy()
#X = X/np.max(X)
Y = Y[:, 3]   # Assuming column 3 is HHB₂
Y = Y.reshape(-1, 1)  # Make it (n_samples, 1) shape for regression
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 X = X.to_numpy()
#       2 Y = Y.to_numpy()
#       3 #X = X/np.max(X)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_numpy'

# %%
np.max(X)
# Out:
# 0.0008265273548387

# %%
Y.shape
# Out:
# (160, 1)

# %%
#from sklearn.preprocessing import StandardScaler
#scaler_X = StandardScaler()
#X = scaler_X.fit_transform(X)

# %% [markdown]
# ### ANN based on pytorch

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split

# %%
# Split into train/test sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Custom PyTorch dataset
class MCXSimDataset(Dataset):
    def __init__(self, X, Y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.Y = torch.tensor(Y, dtype=torch.float32)
    
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        return self.X[idx], self.Y[idx]

# Create DataLoaders
train_loader = DataLoader(MCXSimDataset(X_train, Y_train), batch_size=16, shuffle=True)
test_loader = DataLoader(MCXSimDataset(X_test, Y_test), batch_size=1, shuffle=False)

# %%
class ANN(nn.Module):
    def __init__(self):
        super(ANN, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(96, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(),

            nn.Linear(1024, 2048),
            nn.BatchNorm1d(2048),
            nn.ReLU(),

            nn.Linear(2048, 2048),
            nn.BatchNorm1d(2048),
            nn.ReLU(),

            nn.Linear(2048, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),

            nn.Linear(256, 64),
            nn.BatchNorm1d(64),
            nn.ReLU(),

            nn.Linear(64, 32),
            nn.ReLU(),

            nn.Linear(32, 1)
        )

    def forward(self, x):
        return self.net(x)

model = ANN()

# %% [markdown]
# ### Model training

# %%
#criterion = nn.MSELoss()
criterion = nn.SmoothL1Loss(beta=1.0)
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
num_epochs = 500

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for batch_X, batch_Y in train_loader:
        optimizer.zero_grad()
        outputs = model(batch_X)
        loss = criterion(outputs, batch_Y)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {running_loss / len(train_loader):.4f}")
# Out:
# Epoch 1/500, Loss: 21.2778
# Epoch 2/500, Loss: 20.4398
# Epoch 3/500, Loss: 19.5071
# Epoch 4/500, Loss: 18.4614
# Epoch 5/500, Loss: 17.1156
# Epoch 6/500, Loss: 15.6342
# Epoch 7/500, Loss: 13.8624
# Epoch 8/500, Loss: 11.8940
# Epoch 9/500, Loss: 10.2305
# Epoch 10/500, Loss: 8.0970
# Epoch 11/500, Loss: 6.4289
# Epoch 12/500, Loss: 6.3558
# Epoch 13/500, Loss: 5.5724
# Epoch 14/500, Loss: 4.7435
# Epoch 15/500, Loss: 4.6750
# Epoch 16/500, Loss: 4.3296
# Epoch 17/500, Loss: 3.9635
# Epoch 18/500, Loss: 2.9753
# Epoch 19/500, Loss: 2.6806
# Epoch 20/500, Loss: 2.8989
# Epoch 21/500, Loss: 3.9419
# Epoch 22/500, Loss: 2.7552
# Epoch 23/500, Loss: 3.2871
# Epoch 24/500, Loss: 2.6617
# Epoch 25/500, Loss: 1.9265
# Epoch 26/500, Loss: 2.6142
# Epoch 27/500, Loss: 2.6061
# Epoch 28/500, Loss: 2.9990
# Epoch 29/500, Loss: 2.4650
# Epoch 30/500, Loss: 2.5821
# Epoch 31/500, Loss: 2.4989
# Epoch 32/500, Loss: 1.9369
# Epoch 33/500, Loss: 1.8656
# Epoch 34/500, Loss: 1.6693
# Epoch 35/500, Loss: 1.9693
# Epoch 36/500, Loss: 1.9596
# Epoch 37/500, Loss: 1.7621
# Epoch 38/500, Loss: 2.0128
# Epoch 39/500, Loss: 2.3237
# Epoch 40/500, Loss: 1.9663
# Epoch 41/500, Loss: 1.9797
# Epoch 42/500, Loss: 2.8383
# Epoch 43/500, Loss: 2.3555
# Epoch 44/500, Loss: 1.8643
# Epoch 45/500, Loss: 1.8080
# Epoch 46/500, Loss: 1.9744
# Epoch 47/500, Loss: 1.8849
# Epoch 48/500, Loss: 1.9461
# Epoch 49/500, Loss: 2.2725
# Epoch 50/500, Loss: 2.2405
# Epoch 51/500, Loss: 1.9943
# Epoch 52/500, Loss: 2.0983
# Epoch 53/500, Loss: 1.9687
# Epoch 54/500, Loss: 2.2425
# Epoch 55/500, Loss: 2.4156
# Epoch 56/500, Loss: 1.7422
# Epoch 57/500, Loss: 1.8133
# Epoch 58/500, Loss: 1.8432
# Epoch 59/500, Loss: 2.1153
# Epoch 60/500, Loss: 2.0028
# Epoch 61/500, Loss: 1.7765
# Epoch 62/500, Loss: 2.2179
# Epoch 63/500, Loss: 1.9472
# Epoch 64/500, Loss: 1.7123
# Epoch 65/500, Loss: 1.9255
# Epoch 66/500, Loss: 2.2028
# Epoch 67/500, Loss: 1.8418
# Epoch 68/500, Loss: 1.7695
# Epoch 69/500, Loss: 1.7555
# Epoch 70/500, Loss: 1.4554
# Epoch 71/500, Loss: 2.0132
# Epoch 72/500, Loss: 1.8115
# Epoch 73/500, Loss: 2.0906
# Epoch 74/500, Loss: 1.6626
# Epoch 75/500, Loss: 2.0525
# Epoch 76/500, Loss: 1.4855
# Epoch 77/500, Loss: 1.7012
# Epoch 78/500, Loss: 1.7633
# Epoch 79/500, Loss: 2.1217
# Epoch 80/500, Loss: 2.2728
# Epoch 81/500, Loss: 2.2740
# Epoch 82/500, Loss: 1.6171
# Epoch 83/500, Loss: 1.6307
# Epoch 84/500, Loss: 1.6820
# Epoch 85/500, Loss: 1.8895
# Epoch 86/500, Loss: 1.8119
# Epoch 87/500, Loss: 1.8111
# Epoch 88/500, Loss: 1.9064
# Epoch 89/500, Loss: 2.0126
# Epoch 90/500, Loss: 1.6343
# Epoch 91/500, Loss: 1.8183
# Epoch 92/500, Loss: 1.8558
# Epoch 93/500, Loss: 1.5831
# Epoch 94/500, Loss: 2.0781
# Epoch 95/500, Loss: 1.6385
# Epoch 96/500, Loss: 2.0998
# Epoch 97/500, Loss: 1.6416
# Epoch 98/500, Loss: 1.6653
# Epoch 99/500, Loss: 1.5664
# Epoch 100/500, Loss: 1.4235
# Epoch 101/500, Loss: 1.3786
# Epoch 102/500, Loss: 1.7378
# Epoch 103/500, Loss: 1.5952
# Epoch 104/500, Loss: 1.6175
# Epoch 105/500, Loss: 1.8710
# Epoch 106/500, Loss: 2.1545
# Epoch 107/500, Loss: 1.7437
# Epoch 108/500, Loss: 1.8561
# Epoch 109/500, Loss: 1.7374
# Epoch 110/500, Loss: 1.8423
# Epoch 111/500, Loss: 1.5345
# Epoch 112/500, Loss: 1.9376
# Epoch 113/500, Loss: 1.6768
# Epoch 114/500, Loss: 1.9243
# Epoch 115/500, Loss: 1.8029
# Epoch 116/500, Loss: 1.6965
# Epoch 117/500, Loss: 2.0175
# Epoch 118/500, Loss: 1.2637
# Epoch 119/500, Loss: 1.3955
# Epoch 120/500, Loss: 1.8094
# Epoch 121/500, Loss: 1.6300
# Epoch 122/500, Loss: 2.0057
# Epoch 123/500, Loss: 1.5333
# Epoch 124/500, Loss: 1.8183
# Epoch 125/500, Loss: 1.6007
# Epoch 126/500, Loss: 2.0128
# Epoch 127/500, Loss: 1.6714
# Epoch 128/500, Loss: 2.3063
# Epoch 129/500, Loss: 1.4535
# Epoch 130/500, Loss: 1.2588
# Epoch 131/500, Loss: 1.8439
# Epoch 132/500, Loss: 1.6853
# Epoch 133/500, Loss: 1.5374
# Epoch 134/500, Loss: 2.5837
# Epoch 135/500, Loss: 1.9771
# Epoch 136/500, Loss: 2.0896
# Epoch 137/500, Loss: 1.6965
# Epoch 138/500, Loss: 1.7551
# Epoch 139/500, Loss: 1.8879
# Epoch 140/500, Loss: 1.4824
# Epoch 141/500, Loss: 1.2591
# Epoch 142/500, Loss: 1.7944
# Epoch 143/500, Loss: 2.0105
# Epoch 144/500, Loss: 1.6937
# Epoch 145/500, Loss: 1.4935
# Epoch 146/500, Loss: 1.4873
# Epoch 147/500, Loss: 1.5346
# Epoch 148/500, Loss: 1.4837
# Epoch 149/500, Loss: 1.3278
# Epoch 150/500, Loss: 1.7361
# Epoch 151/500, Loss: 1.8717
# Epoch 152/500, Loss: 1.2300
# Epoch 153/500, Loss: 1.6748
# Epoch 154/500, Loss: 1.6298
# Epoch 155/500, Loss: 1.4964
# Epoch 156/500, Loss: 1.5548
# Epoch 157/500, Loss: 1.9704
# Epoch 158/500, Loss: 2.3017
# Epoch 159/500, Loss: 1.9619
# Epoch 160/500, Loss: 1.7178
# Epoch 161/500, Loss: 1.6143
# Epoch 162/500, Loss: 1.8670
# Epoch 163/500, Loss: 1.9129
# Epoch 164/500, Loss: 1.7251
# Epoch 165/500, Loss: 2.4123
# Epoch 166/500, Loss: 1.7103
# Epoch 167/500, Loss: 1.6189
# Epoch 168/500, Loss: 1.8167
# Epoch 169/500, Loss: 1.7173
# Epoch 170/500, Loss: 1.8335
# Epoch 171/500, Loss: 1.6182
# Epoch 172/500, Loss: 1.4380
# Epoch 173/500, Loss: 1.5911
# Epoch 174/500, Loss: 1.5782
# Epoch 175/500, Loss: 1.7157
# Epoch 176/500, Loss: 1.1116
# Epoch 177/500, Loss: 2.4374
# Epoch 178/500, Loss: 1.2335
# Epoch 179/500, Loss: 2.0169
# Epoch 180/500, Loss: 1.2320
# Epoch 181/500, Loss: 1.2113
# Epoch 182/500, Loss: 1.8715
# Epoch 183/500, Loss: 1.2332
# Epoch 184/500, Loss: 2.1481
# Epoch 185/500, Loss: 1.5652
# Epoch 186/500, Loss: 2.1012
# Epoch 187/500, Loss: 1.5460
# Epoch 188/500, Loss: 1.4619
# Epoch 189/500, Loss: 1.2082
# Epoch 190/500, Loss: 1.6155
# Epoch 191/500, Loss: 1.5068
# Epoch 192/500, Loss: 1.6452
# Epoch 193/500, Loss: 1.6563
# Epoch 194/500, Loss: 1.2835
# Epoch 195/500, Loss: 1.5178
# Epoch 196/500, Loss: 1.1207
# Epoch 197/500, Loss: 1.3988
# Epoch 198/500, Loss: 1.4616
# Epoch 199/500, Loss: 1.5512
# Epoch 200/500, Loss: 1.5332
# Epoch 201/500, Loss: 1.5958
# Epoch 202/500, Loss: 1.7634
# Epoch 203/500, Loss: 2.2210
# Epoch 204/500, Loss: 1.6831
# Epoch 205/500, Loss: 2.1730
# Epoch 206/500, Loss: 1.1531
# Epoch 207/500, Loss: 1.0870
# Epoch 208/500, Loss: 1.3552
# Epoch 209/500, Loss: 1.8764
# Epoch 210/500, Loss: 1.8560
# Epoch 211/500, Loss: 1.9473
# Epoch 212/500, Loss: 1.1642
# Epoch 213/500, Loss: 1.7001
# Epoch 214/500, Loss: 1.8501
# Epoch 215/500, Loss: 1.7799
# Epoch 216/500, Loss: 1.9086
# Epoch 217/500, Loss: 1.3749
# Epoch 218/500, Loss: 1.6966
# Epoch 219/500, Loss: 2.0067
# Epoch 220/500, Loss: 1.4377
# Epoch 221/500, Loss: 1.4497
# Epoch 222/500, Loss: 1.1093
# Epoch 223/500, Loss: 1.6451
# Epoch 224/500, Loss: 1.4914
# Epoch 225/500, Loss: 1.7343
# Epoch 226/500, Loss: 1.7085
# Epoch 227/500, Loss: 1.6118
# Epoch 228/500, Loss: 1.9261
# Epoch 229/500, Loss: 1.4383
# Epoch 230/500, Loss: 1.7365
# Epoch 231/500, Loss: 1.8632
# Epoch 232/500, Loss: 1.6594
# Epoch 233/500, Loss: 1.3959
# Epoch 234/500, Loss: 1.4122
# Epoch 235/500, Loss: 1.6901
# Epoch 236/500, Loss: 1.8791
# Epoch 237/500, Loss: 1.4560
# Epoch 238/500, Loss: 1.5290
# Epoch 239/500, Loss: 1.6108
# Epoch 240/500, Loss: 1.4533
# Epoch 241/500, Loss: 1.6622
# Epoch 242/500, Loss: 1.3928
# Epoch 243/500, Loss: 1.4998
# Epoch 244/500, Loss: 1.8729
# Epoch 245/500, Loss: 1.5085
# Epoch 246/500, Loss: 1.6544
# Epoch 247/500, Loss: 1.5396
# Epoch 248/500, Loss: 1.6451
# Epoch 249/500, Loss: 1.5183
# Epoch 250/500, Loss: 1.7429
# Epoch 251/500, Loss: 1.7206
# Epoch 252/500, Loss: 1.7696
# Epoch 253/500, Loss: 1.8887
# Epoch 254/500, Loss: 1.6122
# Epoch 255/500, Loss: 1.9996
# Epoch 256/500, Loss: 1.7334
# Epoch 257/500, Loss: 1.5153
# Epoch 258/500, Loss: 1.8577
# Epoch 259/500, Loss: 1.6764
# Epoch 260/500, Loss: 1.5862
# Epoch 261/500, Loss: 1.4553
# Epoch 262/500, Loss: 1.8415
# Epoch 263/500, Loss: 1.5783
# Epoch 264/500, Loss: 1.3855
# Epoch 265/500, Loss: 1.4688
# Epoch 266/500, Loss: 1.6725
# Epoch 267/500, Loss: 0.9682
# Epoch 268/500, Loss: 1.1565
# Epoch 269/500, Loss: 1.2127
# Epoch 270/500, Loss: 1.4299
# Epoch 271/500, Loss: 2.0243
# Epoch 272/500, Loss: 1.7786
# Epoch 273/500, Loss: 1.4048
# Epoch 274/500, Loss: 1.4378
# Epoch 275/500, Loss: 2.6803
# Epoch 276/500, Loss: 1.4151
# Epoch 277/500, Loss: 1.6206
# Epoch 278/500, Loss: 1.2366
# Epoch 279/500, Loss: 1.7307
# Epoch 280/500, Loss: 1.3649
# Epoch 281/500, Loss: 1.2881
# Epoch 282/500, Loss: 1.5519
# Epoch 283/500, Loss: 1.0038
# Epoch 284/500, Loss: 1.4323
# Epoch 285/500, Loss: 2.1721
# Epoch 286/500, Loss: 1.5313
# Epoch 287/500, Loss: 1.4088
# Epoch 288/500, Loss: 2.0391
# Epoch 289/500, Loss: 2.0478
# Epoch 290/500, Loss: 1.8056
# Epoch 291/500, Loss: 1.9066
# Epoch 292/500, Loss: 1.5325
# Epoch 293/500, Loss: 1.6081
# Epoch 294/500, Loss: 1.4428
# Epoch 295/500, Loss: 1.6782
# Epoch 296/500, Loss: 1.5778
# Epoch 297/500, Loss: 1.4546
# Epoch 298/500, Loss: 1.5081
# Epoch 299/500, Loss: 1.8261
# Epoch 300/500, Loss: 1.3619
# Epoch 301/500, Loss: 1.9613
# Epoch 302/500, Loss: 1.7434
# Epoch 303/500, Loss: 1.8385
# Epoch 304/500, Loss: 1.5111
# Epoch 305/500, Loss: 1.8354
# Epoch 306/500, Loss: 1.6291
# Epoch 307/500, Loss: 1.5643
# Epoch 308/500, Loss: 1.3777
# Epoch 309/500, Loss: 1.4706
# Epoch 310/500, Loss: 1.9832
# Epoch 311/500, Loss: 1.5048
# Epoch 312/500, Loss: 1.0028
# Epoch 313/500, Loss: 1.2870
# Epoch 314/500, Loss: 1.3685
# Epoch 315/500, Loss: 1.4589
# Epoch 316/500, Loss: 1.4482
# Epoch 317/500, Loss: 2.3465
# Epoch 318/500, Loss: 1.4310
# Epoch 319/500, Loss: 1.4708
# Epoch 320/500, Loss: 2.0061
# Epoch 321/500, Loss: 1.1522
# Epoch 322/500, Loss: 1.7855
# Epoch 323/500, Loss: 1.8607
# Epoch 324/500, Loss: 1.7795
# Epoch 325/500, Loss: 1.6496
# Epoch 326/500, Loss: 1.2631
# Epoch 327/500, Loss: 1.2337
# Epoch 328/500, Loss: 1.1229
# Epoch 329/500, Loss: 1.3596
# Epoch 330/500, Loss: 1.9007
# Epoch 331/500, Loss: 1.2730
# Epoch 332/500, Loss: 1.2892
# Epoch 333/500, Loss: 1.5036
# Epoch 334/500, Loss: 1.4591
# Epoch 335/500, Loss: 1.3155
# Epoch 336/500, Loss: 1.5615
# Epoch 337/500, Loss: 1.8564
# Epoch 338/500, Loss: 1.6032
# Epoch 339/500, Loss: 1.2512
# Epoch 340/500, Loss: 1.8070
# Epoch 341/500, Loss: 1.5502
# Epoch 342/500, Loss: 1.4539
# Epoch 343/500, Loss: 2.0599
# Epoch 344/500, Loss: 1.5455
# Epoch 345/500, Loss: 1.5882
# Epoch 346/500, Loss: 1.5808
# Epoch 347/500, Loss: 1.3432
# Epoch 348/500, Loss: 1.4519
# Epoch 349/500, Loss: 1.7247
# Epoch 350/500, Loss: 0.9999
# Epoch 351/500, Loss: 1.4584
# Epoch 352/500, Loss: 1.0973
# Epoch 353/500, Loss: 1.5995
# Epoch 354/500, Loss: 1.8075
# Epoch 355/500, Loss: 1.3260
# Epoch 356/500, Loss: 1.9406
# Epoch 357/500, Loss: 1.3995
# Epoch 358/500, Loss: 1.0794
# Epoch 359/500, Loss: 1.6105
# Epoch 360/500, Loss: 1.0431
# Epoch 361/500, Loss: 1.8697
# Epoch 362/500, Loss: 1.5604
# Epoch 363/500, Loss: 1.1590
# Epoch 364/500, Loss: 1.5576
# Epoch 365/500, Loss: 1.4429
# Epoch 366/500, Loss: 1.5910
# Epoch 367/500, Loss: 1.8364
# Epoch 368/500, Loss: 1.4534
# Epoch 369/500, Loss: 1.4164
# Epoch 370/500, Loss: 1.5662
# Epoch 371/500, Loss: 1.2250
# Epoch 372/500, Loss: 1.4809
# Epoch 373/500, Loss: 1.3853
# Epoch 374/500, Loss: 1.8963
# Epoch 375/500, Loss: 1.4281
# Epoch 376/500, Loss: 2.0777
# Epoch 377/500, Loss: 1.5551
# Epoch 378/500, Loss: 1.6818
# Epoch 379/500, Loss: 1.2535
# Epoch 380/500, Loss: 1.1284
# Epoch 381/500, Loss: 1.9852
# Epoch 382/500, Loss: 1.4714
# Epoch 383/500, Loss: 1.1589
# Epoch 384/500, Loss: 1.3145
# Epoch 385/500, Loss: 2.0013
# Epoch 386/500, Loss: 1.1773
# Epoch 387/500, Loss: 1.6857
# Epoch 388/500, Loss: 2.0764
# Epoch 389/500, Loss: 1.5835
# Epoch 390/500, Loss: 1.5768
# Epoch 391/500, Loss: 1.2655
# Epoch 392/500, Loss: 1.5818
# Epoch 393/500, Loss: 1.4213
# Epoch 394/500, Loss: 1.6193
# Epoch 395/500, Loss: 1.6406
# Epoch 396/500, Loss: 1.2647
# Epoch 397/500, Loss: 1.1889
# Epoch 398/500, Loss: 1.5328
# Epoch 399/500, Loss: 1.4086
# Epoch 400/500, Loss: 1.0061
# Epoch 401/500, Loss: 1.3365
# Epoch 402/500, Loss: 1.1744
# Epoch 403/500, Loss: 1.5807
# Epoch 404/500, Loss: 1.3249
# Epoch 405/500, Loss: 1.2492
# Epoch 406/500, Loss: 1.5623
# Epoch 407/500, Loss: 1.1187
# Epoch 408/500, Loss: 1.4741
# Epoch 409/500, Loss: 1.5263
# Epoch 410/500, Loss: 1.3401
# Epoch 411/500, Loss: 1.2957
# Epoch 412/500, Loss: 1.1228
# Epoch 413/500, Loss: 1.3888
# Epoch 414/500, Loss: 1.1652
# Epoch 415/500, Loss: 1.1854
# Epoch 416/500, Loss: 1.2414
# Epoch 417/500, Loss: 1.7206
# Epoch 418/500, Loss: 1.4984
# Epoch 419/500, Loss: 1.3206
# Epoch 420/500, Loss: 1.4850
# Epoch 421/500, Loss: 1.1859
# Epoch 422/500, Loss: 1.4232
# Epoch 423/500, Loss: 1.1825
# Epoch 424/500, Loss: 1.4113
# Epoch 425/500, Loss: 1.2079
# Epoch 426/500, Loss: 1.2725
# Epoch 427/500, Loss: 1.4453
# Epoch 428/500, Loss: 1.5826
# Epoch 429/500, Loss: 1.3689
# Epoch 430/500, Loss: 1.2761
# Epoch 431/500, Loss: 1.2290
# Epoch 432/500, Loss: 1.2344
# Epoch 433/500, Loss: 1.4680
# Epoch 434/500, Loss: 0.8206
# Epoch 435/500, Loss: 1.7447
# Epoch 436/500, Loss: 1.0484
# Epoch 437/500, Loss: 1.1800
# Epoch 438/500, Loss: 1.2857
# Epoch 439/500, Loss: 0.9844
# Epoch 440/500, Loss: 1.1956
# Epoch 441/500, Loss: 1.7382
# Epoch 442/500, Loss: 2.2577
# Epoch 443/500, Loss: 1.3019
# Epoch 444/500, Loss: 1.2655
# Epoch 445/500, Loss: 1.4053
# Epoch 446/500, Loss: 1.2263
# Epoch 447/500, Loss: 1.6345
# Epoch 448/500, Loss: 1.6126
# Epoch 449/500, Loss: 1.3195
# Epoch 450/500, Loss: 1.0556
# Epoch 451/500, Loss: 1.5644
# Epoch 452/500, Loss: 1.6976
# Epoch 453/500, Loss: 1.8092
# Epoch 454/500, Loss: 1.3123
# Epoch 455/500, Loss: 1.4219
# Epoch 456/500, Loss: 1.2192
# Epoch 457/500, Loss: 1.3968
# Epoch 458/500, Loss: 1.2895
# Epoch 459/500, Loss: 1.5816
# Epoch 460/500, Loss: 1.2700
# Epoch 461/500, Loss: 2.1879
# Epoch 462/500, Loss: 1.6327
# Epoch 463/500, Loss: 1.1765
# Epoch 464/500, Loss: 1.5826
# Epoch 465/500, Loss: 1.5838
# Epoch 466/500, Loss: 1.3358
# Epoch 467/500, Loss: 1.3090
# Epoch 468/500, Loss: 1.3160
# Epoch 469/500, Loss: 1.6792
# Epoch 470/500, Loss: 1.0817
# Epoch 471/500, Loss: 1.6277
# Epoch 472/500, Loss: 1.3125
# Epoch 473/500, Loss: 1.3236
# Epoch 474/500, Loss: 1.4367
# Epoch 475/500, Loss: 1.8306
# Epoch 476/500, Loss: 1.2488
# Epoch 477/500, Loss: 1.0322
# Epoch 478/500, Loss: 1.1046
# Epoch 479/500, Loss: 1.3223
# Epoch 480/500, Loss: 1.4266
# Epoch 481/500, Loss: 1.2126
# Epoch 482/500, Loss: 1.8537
# Epoch 483/500, Loss: 1.2089
# Epoch 484/500, Loss: 1.3986
# Epoch 485/500, Loss: 1.3470
# Epoch 486/500, Loss: 1.6829
# Epoch 487/500, Loss: 1.7217
# Epoch 488/500, Loss: 0.9933
# Epoch 489/500, Loss: 1.3510
# Epoch 490/500, Loss: 1.3773
# Epoch 491/500, Loss: 1.3651
# Epoch 492/500, Loss: 1.4897
# Epoch 493/500, Loss: 1.3168
# Epoch 494/500, Loss: 1.2634
# Epoch 495/500, Loss: 1.7553
# Epoch 496/500, Loss: 1.6831
# Epoch 497/500, Loss: 1.7161
# Epoch 498/500, Loss: 1.4054
# Epoch 499/500, Loss: 1.5960
# Epoch 500/500, Loss: 1.5750

# %%
model.eval()
all_preds = []
all_targets = []

with torch.no_grad():
    total_mse = 0
    for batch_X, batch_Y in test_loader:
        preds = model(batch_X)
        print('preds=', preds)
        print('GT   =', batch_Y)
        print('---------')
        all_preds.append(preds.numpy())
        all_targets.append(batch_Y.numpy())
        mse = criterion(preds, batch_Y)
        total_mse += mse.item()
    print(f"Test MSE: {total_mse / len(test_loader):.4f}")
# Out:
# preds= tensor([[12.4126]])
# GT   = tensor([[27.]])
# ---------
# preds= tensor([[11.0922]])
# GT   = tensor([[29.]])
# ---------
# preds= tensor([[11.6861]])
# GT   = tensor([[17.]])
# ---------
# preds= tensor([[11.5508]])
# GT   = tensor([[33.]])
# ---------
# preds= tensor([[18.0830]])
# GT   = tensor([[23.]])
# ---------
# preds= tensor([[30.6352]])
# GT   = tensor([[23.]])
# ---------
# preds= tensor([[29.5160]])
# GT   = tensor([[25.]])
# ---------
# preds= tensor([[12.9802]])
# GT   = tensor([[31.]])
# ---------
# preds= tensor([[18.5864]])
# GT   = tensor([[25.]])
# ---------
# preds= tensor([[15.2274]])
# GT   = tensor([[17.]])
# ---------
# preds= tensor([[9.9195]])
# GT   = tensor([[21.]])
# ---------
# preds= tensor([[9.9051]])
# GT   = tensor([[21.]])
# ---------
# preds= tensor([[12.8066]])
# GT   = tensor([[19.]])
# ---------
# preds= tensor([[9.5422]])
# GT   = tensor([[15.]])
# ---------
# preds= tensor([[10.2141]])
# GT   = tensor([[23.]])
# ---------
# preds= tensor([[10.4705]])
# GT   = tensor([[25.]])
# ---------
# preds= tensor([[11.2069]])
# GT   = tensor([[35.]])
# ---------
# preds= tensor([[11.7632]])
# GT   = tensor([[19.]])
# ---------
# preds= tensor([[10.4420]])
# GT   = tensor([[25.]])
# ---------
# preds= tensor([[19.5411]])
# GT   = tensor([[19.]])
# ---------
# preds= tensor([[12.1845]])
# GT   = tensor([[17.]])
# ---------
# preds= tensor([[9.9623]])
# GT   = tensor([[21.]])
# ---------
# preds= tensor([[9.7079]])
# GT   = tensor([[19.]])
# ---------
# preds= tensor([[12.7572]])
# GT   = tensor([[17.]])
# ---------
# preds= tensor([[10.3209]])
# GT   = tensor([[25.]])
# ---------
# preds= tensor([[9.8113]])
# GT   = tensor([[21.]])
# ---------
# preds= tensor([[10.2301]])
# GT   = tensor([[25.]])
# ---------
# preds= tensor([[11.2987]])
# GT   = tensor([[33.]])
# ---------
# preds= tensor([[32.2888]])
# GT   = tensor([[35.]])
# ---------
# preds= tensor([[10.5954]])
# GT   = tensor([[27.]])
# ---------
# preds= tensor([[15.0517]])
# GT   = tensor([[15.]])
# ---------
# preds= tensor([[9.6898]])
# GT   = tensor([[19.]])
# ---------
# Test MSE: 9.8301

# %%
import matplotlib.pyplot as plt
import numpy as np
all_preds = np.array(all_preds).squeeze(1).squeeze(1)
all_targets = np.array(all_targets).squeeze(1).squeeze(1)

plt.figure(figsize=(10, 5))

plt.plot(all_targets, label='Ground Truth (HHB2)', color='red', linewidth=2, marker='o', markersize=5)
plt.plot(all_preds, label='Predicted (HHB2)', color='blue', linestyle='--', linewidth=2, marker='o', markersize=5)

plt.xlabel('Sample Index (Run)')
plt.ylabel('HHB2 Concentration')
plt.title('Predicted vs Ground Truth - HHB2')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### XGboost

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=1000, max_depth=8, learning_rate=0.05)
model.fit(X_train, y_train)
# Out:
# (128, 96) (32, 96) (128, 1) (32, 1)
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=8,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=1000,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_preds = np.column_stack([model.predict(X_test)])
mse = np.mean((y_preds - y_test)**2, axis=0)

# %%
mse
# Out:
# array([9.46372851])

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(16, 8))

plt.plot(y_test, label='Ground Truth (HHB2)', color='red', linewidth=2, marker='o', markersize=5)
plt.plot(y_preds, label='Predicted (HHB2)', color='blue', linestyle='--', linewidth=2, marker='o', markersize=5)

plt.xlabel('Sample Index (Run)')
plt.ylabel('HHB2 Concentration')
plt.title(f'HHB2 mse : {mse}')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
